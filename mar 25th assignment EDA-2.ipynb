# %% [markdown]
# # Flight Price:

# %% [markdown]
# ## Q1. Load the flight price dataset and examine its dimensions. How many rows and columns does the dataset have?

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\tanji\Desktop\myPW\notes\Datasets\flight_price.csv")
df.shape
# Out:
# (10683, 11)

# %% [markdown]
# - The flight dataset has 10683 rows and 11 columns

# %% [markdown]
# ## Q2. What is the distribution of flight prices in the dataset? Create a histogram to visualize the distribution.

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL  \
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
sns.histplot(data=df, x='Price', kde=True)
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %% [markdown]
# - The distribution of filgit prices is right skewed

# %% [markdown]
# ## Q3. What is the range of prices in the dataset? What is the minimum and maximum price?

# %%
print(f"Flight price range [{df['Price'].min()} , {df['Price'].max()}]")
print(f"Maximum price: {df['Price'].max()} , Minimum Price : {df['Price'].min()}")
# Out:
# Flight price range [1759 , 79512]
# Maximum price: 79512 , Minimum Price : 1759

# %% [markdown]
# ## Q4. How does the price of flights vary by airline? Create a boxplot to compare the prices of different airlines.

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='Airline', y='Price', data=df)
plt.xticks(rotation=45)
plt.title('Price Variation by Airline')
plt.xlabel('Airline')
plt.ylabel('Price')
plt.tight_layout()
plt.show()

# %% [markdown]
# - Vistara Premium economy Airline has very high prices when compared to other Airlines
# - All other airlines have their median cost below 150000

# %% [markdown]
# ## Q5. Are there any outliers in the dataset? Identify any potential outliers using a boxplot and describe howthey may impact your analysis.

# %%
sns.boxplot(df['Price'], orient='h')
# Out:
# <Axes: >

# %% [markdown]
# - We could see various outliers in Price feature, but this can be valid as business class cost more than economy class.
#
# A invalid outlier may skew the distribution and lead to inefficient models

# %% [markdown]
# ## Q6. You are working for a travel agency, and your boss has asked you to analyze the Flight Price dataset to identify the peak travel season. What features would you analyze to identify the peak season, and how would you present your findings to your boss?
#
#
# **Features to Analyze:**
#
# 1. **Date/Time Information:** Check for patterns in flight prices based on months, weeks, or specific dates. Seasonal holidays, vacations, and festivals can influence peak travel seasons.
#
# 2. **Number of Bookings or Passengers:** Analyze the number of bookings or passengers during different time periods. Higher booking rates indicate peak travel seasons.
#
# 3. **Price Fluctuations:** Look for periods of consistent price fluctuations. Sharp increases in prices might indicate high demand and peak seasons.
#
# 4. **Day of the Week:** Analyze if flight prices are influenced by the day of the week. Fridays and Sundays, for example, are often popular travel days.
#
#
# **Communication:**
#
# When presenting your findings to your boss:
#
# 1. **Visual Aids:** Use clear and visually appealing charts and graphs to support your analysis. Visual aids make it easier for your boss to understand the data trends.
#
# 2. **Narrative:** Tell a story with your data. Walk your boss through the analysis step by step, explaining the significance of each finding.
#
# 3. **Highlight Key Points:** Emphasize the key peak travel seasons and explain why they are important for the agency's business.
#
# 4. **Recommendations:** Offer actionable recommendations based on your analysis. Suggest strategies to capitalize on the peak travel seasons, such as targeted marketing campaigns or special promotions.
#
# 5. **Interactive Presentation:** Create an interactive dashboard that allows your boss to explore the data and trends on their own.

# %% [markdown]
# ## Q7. You are a data analyst for a flight booking website, and you have been asked to analyze the Flight Price dataset to identify any trends in flight prices. What features would you analyze to identify these trends, and what visualizations would you use to present your findings to your team?
#
#
# **Features to Analyze:**
#
# 1. **Date/Time Information:** Analyze how flight prices change over time, considering factors like months, weeks, and specific dates. This can help identify seasonal trends.
#
# 2. **Flight Routes and Destinations:** Investigate how prices vary based on different flight routes and destinations. Identify popular routes with consistent price trends.
#
# 3. **Airline Comparison:** Compare flight prices among different airlines to see if certain airlines consistently offer higher or lower prices.
#
# 4. **Day of the Week:** Investigate whether flight prices vary depending on the day of the week, as certain days might have cheaper prices.
#
# 5. **Number of Layovers or Stops:** Examine how the number of layovers or stops in a flight affects its price.
#
# 6. **Flight Duration:** Check if flight duration correlates with higher or lower prices.
#
# **Visualizations to Present Findings:**
#
# 1. **Time Series Line Plot:** Create a line plot with time on the x-axis and average flight prices on the y-axis. Use different colors or markers for different years or months to show seasonal trends.
#
# 2. **Bar Charts for Routes/Destinations:** Use bar charts to compare average flight prices for different flight routes or destinations. Highlight routes with notable price differences.
#
# 3. **Box Plots for Airlines:** Create box plots to compare flight prices among different airlines. Highlight the median, quartiles, and outliers to show the price distribution.
#
# 4. **Advance Booking Scatter Plot:** Generate a scatter plot with the number of days in advance on the x-axis and flight prices on the y-axis. Observe if there's a noticeable trend.
#
# 5. **Day of the Week Bar Chart:** Use a bar chart to display average flight prices for each day of the week. This can show if specific days have consistently lower or higher prices.
#
# 6. **Scatter Plot for Layovers/Duration:** Create a scatter plot with the number of layovers or flight duration on the x-axis and flight prices on the y-axis. Look for any patterns.
#
# 7. **Heatmap:** Use a heatmap to visualize the relationship between flight prices and different features like departure time, duration, and layovers.

# %% [markdown]
# ## Q8. You are a data scientist working for an airline company, and you have been asked to analyze the Flight Price dataset to identify the factors that affect flight prices. What features would you analyze to identify these factors, and how would you present your findings to the management team?
#
# As a data scientist analyzing the Flight Price dataset to identify factors that affect flight prices for an airline company, you would focus on various features that could influence pricing. Here's a step-by-step approach on what features to analyze and how to present your findings to the management team:
#
# **Features to Analyze:**
#
# 1. **Date/Time Information:** Investigate how flight prices vary over different time periods, such as months, weeks, and specific dates. Consider seasonal trends, holidays, and peak travel seasons.
#
# 2. **Flight Routes and Destinations:** Analyze the impact of different flight routes and destinations on prices. Identify popular routes and high-demand destinations.
#
# 3. **Airline and Aircraft Type:** Examine how flight prices differ among various airlines and aircraft types. Certain airlines or aircraft might offer different levels of service and amenities.
#
# 4. **Day of the Week:** Analyze whether flight prices vary based on the day of the week. Some days might have higher demand and prices.
#
# 5. **Number of Layovers or Stops:** Investigate how the number of layovers or stops in a flight affects its price. Non-stop flights might have different pricing than those with layovers.
#
# 6. **Flight Duration:** Examine the relationship between flight duration and prices. Longer flights might have higher prices due to increased fuel and operational costs.
#
# 7. **Cabin Class and Seat Type:** Analyze how prices vary based on cabin class (economy, business, first) and seat type (standard, premium, etc.).
#
# 8. **Competition and Market Factors:** Consider the competitive landscape and market conditions, such as the presence of other airlines on the same routes.
#
# **Presenting Findings to Management:**
#
# 1. **Data Visualization:** Use various types of visualizations, such as line charts, bar charts, scatter plots, and heatmaps, to present your findings. Visualizations make complex patterns easier to understand.
#
# 2. **Key Insights:** Summarize the key insights you've gathered from the analysis. Highlight trends, correlations, and significant factors affecting flight prices.
#
# 3. **Interactive Dashboards :** If feasible, create an interactive dashboard that allows management to explore different factors and their effects on flight prices.
#
# 4. **Comparative Analysis:** Compare different features using side-by-side visualizations to highlight the variations in flight prices based on each factor.
#
# 5. **Regression Analysis:** Perform regression analysis to quantify the impact of each factor on flight prices. Provide regression coefficients and p-values to show the strength and significance of relationships.
#
# 6. **Scenario Analysis (Optional):** Explore "what-if" scenarios to demonstrate how changes in certain factors could impact flight prices. This can help management understand the potential outcomes of different decisions.
#
# 7. **Recommendations:** Based on your analysis, provide actionable recommendations to the management team. Suggest strategies to optimize pricing, improve revenue, and enhance customer satisfaction.

# %% [markdown]
# # Google Playstore:

# %% [markdown]
# ## Q9. Load the Google Playstore dataset and examine its dimensions. How many rows and columns does the dataset have?

# %%
df1=pd.read_csv('https://raw.githubusercontent.com/krishnaik06/playstore-Dataset/main/googleplaystore.csv')
df1.shape
# Out:
# (10841, 13)

# %% [markdown]
# - The dataset has 10841 rows and 13 columns

# %% [markdown]
# ## Q10. How does the rating of apps vary by category? Create a boxplot to compare the ratings of different app categories.

# %%
df1.groupby('Category')['Rating'].mean()
# Out:
# Category
# 1.9                    19.000000
# ART_AND_DESIGN          4.358065
# AUTO_AND_VEHICLES       4.190411
# BEAUTY                  4.278571
# BOOKS_AND_REFERENCE     4.346067
# BUSINESS                4.121452
# COMICS                  4.155172
# COMMUNICATION           4.158537
# DATING                  3.970769
# EDUCATION               4.389032
# ENTERTAINMENT           4.126174
# EVENTS                  4.435556
# FAMILY                  4.192272
# FINANCE                 4.131889
# FOOD_AND_DRINK          4.166972
# GAME                    4.286326
# HEALTH_AND_FITNESS      4.277104
# HOUSE_AND_HOME          4.197368
# LIBRARIES_AND_DEMO      4.178462
# LIFESTYLE               4.094904
# MAPS_AND_NAVIGATION     4.051613
# MEDICAL                 4.189143
# NEWS_AND_MAGAZINES      4.132189
# PARENTING               4.300000
# PERSONALIZATION         4.335987
# PHOTOGRAPHY             4.192114
# PRODUCTIVITY            4.211396
# SHOPPING                4.259664
# ...

# %%
df1[df1['Category']=='1.9']
# Out:
#                                            App Category  Rating Reviews
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M  \
#
#          Size Installs Type     Price Content Rating             Genres
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018  \
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
#droping the above corrupt datapoint
df1=df1.drop(10472)

# %%
plt.figure(figsize=(10,10))
sns.boxplot(data=df1,x='Category', y='Rating')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Q11. Are there any missing values in the dataset? Identify any missing values and describe how they may impact your analysis.

# %%
df1.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          2
# dtype: int64

# %% [markdown]
# - Yes, there are major values missing in Rating column, while minor missing values in Type, Android ver and Current Ver.
# - Rating is an important feature to understand the popularity of an app. Thus trying to impute them may result in false values.
# - Android ver is very much necessary to understand how many people use it. Because the popularity of the app is dependent on the affordability and availability of the app
# - Other missing features doesnt have much significant impact on popularity

# %% [markdown]
# ## Q12. What is the relationship between the size of an app and its rating? Create a scatter plot to visualize the relationship.

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(data=df1,x='Size', y='Rating')
# Out:
# <Axes: xlabel='Size', ylabel='Rating'>

# %% [markdown]
# - There is no linear relation between Size and Rating.
# - Apps within a median size tends to have higher rating
# - Apps with larger size are in low numbers but manages to get a rating of 2.0 or above

# %% [markdown]
# ## Q13. How does the type of app affect its price? Create a bar chart to compare average prices by app type.

# %%
#Converting Price to float
df1['Price']=df1['Price'].str.replace("$","").astype(float)

# %%
new_df=df1.groupby('Type')['Price'].mean()
new_df
# Out:
# Type
# Free     0.000000
# Paid    13.920837
# Name: Price, dtype: float64

# %%
new_df.plot(kind='bar')
# Out:
# <Axes: xlabel='Type'>

# %% [markdown]
# - Free apps have a mean price of \$0
# - Paid apps have a mean price of \$13.920837

# %% [markdown]
# ## Q14. What are the top 10 most popular apps in the dataset? Create a frequency table to identify the apps with the highest number of installs.

# %%
df1['Installs']=df1['Installs'].str.replace("+","").str.replace(",","").astype(int) #replace + and ,

# %%
df3=df1.groupby('App')['Installs'].sum().sort_values(ascending=False).head(10)
df3
# Out:
# App
# Subway Surfers                  6000000000
# Google News                     4000000000
# Hangouts                        4000000000
# Google Drive                    4000000000
# Google Photos                   4000000000
# Instagram                       4000000000
# Candy Crush Saga                3500000000
# Maps - Navigate & Explore       3000000000
# Google Chrome: Fast & Secure    3000000000
# WhatsApp Messenger              3000000000
# Name: Installs, dtype: int64

# %%
df3.plot(kind='bar')
# Out:
# <Axes: xlabel='App'>

# %% [markdown]
# ## Q15. A company wants to launch a new app on the Google Playstore and has asked you to analyze the Google Playstore dataset to identify the most popular app categories. How would you approach this task, and what features would you analyze to make recommendations to the company?
